# %% [markdown]
# # My Jupyter Notebook On IBM Watson Studio

# %% [markdown]
# **Janki Panchal**

# %% [markdown]
# IT Business Analyst

# %% [markdown]
# *I am interested in Data science because I love to amalyze, visualize and manipulate data. Moreover I ama interested in machine learning & deep learning.*

# %% [markdown]
# #### This code shows the graphical representation of an array

# %%
import numpy as np 
import seaborn as sb 

x= np.array([10,20,30,4,5,6,70])
sb.distplot(x)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>DESCRIPTION</b>
#
#   </div>

# %% [markdown]
#
# 1. Numpy
#  - It is a python library used for working with arrays.
# 2. Seaborn
#  - It is a python library used for working with statistical operations. t builts on top of matplotlib and integrates closely with pandas data structures.
